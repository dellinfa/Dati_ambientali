# %%
IMPORT LIBRERIE E DATASET POLLUTANT RELEASE

# %%
#import dataset e librerie 

import numpy as np
import pandas as pd

df = pd.read_csv('Pollutant_Release_new.csv' ,sep =';')


df.head()
# Out:
#    FacilityID    NationalID                                   FacilityName  \
# 0      192129  1124.0040.02                     Sele avfallsplass - Deponi
# 1      192129  1124.0040.02                     Sele avfallsplass - Deponi
# 2      192129  1124.0040.02                     Sele avfallsplass - Deponi
# 3        4659     06K000239  ArcelorMittal Poland S.A., Oddzia? w Krakowie
# 4        4659     06K000239  ArcelorMittal Poland S.A., Oddzia? w Krakowie
#
#        StreetName BuildingNumber PostalCode    City CountryName         Lat  \
# 0  Kleppvegen 837            NaN       4354    Voll      Norway  58,8203773
# 1  Kleppvegen 837            NaN       4354    Voll      Norway  58,8203773
# 2  Kleppvegen 837            NaN       4354    Voll      Norway  58,8203773
# 3       Ujastek 1            NaN     30-969  Krak�w      Poland   50,080333
# 4       Ujastek 1            NaN     30-969  Krak�w      Poland   50,080333
#
# ...

# %%
df.tail()
# Out:
#         FacilityID           NationalID      FacilityName        StreetName  \
# 652346       45039         07-01-114014  Rasselstein GmbH    Koblenzer Str.
# 652347       45039         07-01-114014  Rasselstein GmbH    Koblenzer Str.
# 652348       45039         07-01-114014  Rasselstein GmbH    Koblenzer Str.
# 652349       45706  06-09-162-0025-0001      BMW Werk 1.1  Lerchenauer Str.
# 652350       46133  06-09-775-2109-0001       EvoBus GmbH   Carl-Zeiss-Str.
#
#        BuildingNumber PostalCode       City CountryName          Lat  \
# 652346            141      56626  Andernach     Germany  50,43481013
# 652347            141      56626  Andernach     Germany  50,43481013
# 652348            141      56626  Andernach     Germany  50,43481013
# 652349             76      80788    M�nchen     Germany  48,17917516
# 652350              2      89231    Neu-Ulm     Germany  48,39309564
#
#                Long  ... MainIAActivityCode  \
# 652346  7,426398842  ...              2.(f)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652351 entries, 0 to 652350
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   FacilityID              652351 non-null  int64
#  1   NationalID              652351 non-null  object
#  2   FacilityName            651263 non-null  object
#  3   StreetName              645937 non-null  object
#  4   BuildingNumber          418206 non-null  object
#  5   PostalCode              650638 non-null  object
#  6   City                    638945 non-null  object
#  7   CountryName             652351 non-null  object
#  8   Lat                     652351 non-null  object
#  9   Long                    652351 non-null  object
#  10  CompetentAuthorityName  652351 non-null  object
#  11  MainIAActivityCode      652351 non-null  object
#  12  MainIASectorName        652351 non-null  object
#  13  MainIAActivityName      652351 non-null  object
# ...

# %%
df['ReleaseMediumName'].value_counts()
# Out:
# Air      392948
# Water    256100
# Soil       3303
# Name: ReleaseMediumName, dtype: int64

# %%
df['PollutantGroupName'].value_counts()
# Out:
# Other gases                       214803
# Heavy metals                      162093
# Greenhouse gases                   90362
# Inorganic substances               82623
# Other organic substances           69843
# Chlorinated organic substances     29707
# Pesticides                          2920
# Name: PollutantGroupName, dtype: int64

# %%
italia = df.loc[(df['CountryName'] == 'Italy') & (df['City'] == 'TORINO')]
italia
# Out:
#         FacilityID  NationalID  \
# 2358            69    01001010
# 2499            70    01001011
# 2500            70    01001011
# 2501            70    01001011
# 3224            70    01001011
# ...            ...         ...
# 563133          87  2007001835
# 572611      191451  2008000003
# 576054          81  2007001836
# 576055          81  2007001836
# 576056          81  2007001836
#
#                                              FacilityName  \
# 2358    AZIENDA ENERGETICA METROPOLITANA TORINO S.P.A....
# 2499    AZIENDA ENERGETICA METROPOLITANA TORINO S.P.A....
# 2500    AZIENDA ENERGETICA METROPOLITANA TORINO S.P.A....
# 2501    AZIENDA ENERGETICA METROPOLITANA TORINO S.P.A....
# 3224    AZIENDA ENERGETICA METROPOLITANA TORINO S.P.A....
# ...                                                   ...
# 563133         Comprensorio industriale di Mirafiori (TO)
# 572611         Luigi Lavazza SpA - Stabilimento di Torino
# ...

# %%
#trasformo quantità di inquinante misurato in kg in float usando una funzione lambda

df['TotalQuantity'].apply(lambda x: float(x.replace(',','.')))
# Out:
# 0          53300.0000
# 1              3.0900
# 2              0.0482
# 3            190.0000
# 4         536000.0000
#              ...
# 652346       131.0000
# 652347     80700.0000
# 652348       184.0000
# 652349    374000.0000
# 652350    288000.0000
# Name: TotalQuantity, Length: 652351, dtype: float64
