# %% [markdown]
# IMPORT LIBRERIE E DATASET SULLA QUALITA' DI ARIA E ACQUA

# %%
#import dataset e librerie 

import numpy as np
import pandas as pd

df = pd.read_csv('Facilities_new.csv' ,sep =';')


df.head()
# Out:
#    FacilityID    NationalID  \
# 0      192268  1504.0090.01
# 1      192338  1721.0056.03
# 2      192129  1124.0040.02
# 3        4659     06K000239
# 4        5119     08O000439
#
#                                         FacilityName      StreetName  \
# 0                               Bingsa avfallsdeponi      Alvikveien
# 1                   Skj�rdalen avfallsplass - deponi  Russervegen 10
# 2                         Sele avfallsplass - Deponi  Kleppvegen 837
# 3      ArcelorMittal Poland S.A., Oddzia? w Krakowie       Ujastek 1
# 4  Grupa Azoty Zak?ady Azotowe K?dzierzyn Sp�?ka ...     Mostowa 30a
#
#   BuildingNumber PostalCode              City CountryName         Lat  \
# 0            NaN       6018           �lesund      Norway   62,482872
# 1            NaN       7652            Verdal      Norway  63,7457275
# 2            NaN       4354              Voll      Norway  58,8203773
# 3            NaN     30-969            Krak�w      Poland   50,080333
# ...

# %%
#guardo anche la coda
df.tail()
# Out:
#         FacilityID           NationalID  \
# 418464       46133  06-09-775-2109-0001
# 418465       46252     06-11-01-1108101
# 418466       46258     06-11-01-1600501
# 418467       74753    14-80-56175410000
# 418468       46908                15170
#
#                                              FacilityName          StreetName  \
# 418464                                        EvoBus GmbH     Carl-Zeiss-Str.
# 418465                                 impress d�cor GmbH          Alboinstr.
# 418466                   BAGR Berliner Aluminiumwerk GmbH   Kopenhagener Str.
# 418467  Vopelius Chemie AG Gesch�ftsbereich Galvano Ch...     Torgauer Stra�e
# 418468   MKM Mansfelder Kupfer und Messing Kazakmyhs GmbH  Lichtl�cherberg 40
#
#        BuildingNumber PostalCode       City CountryName          Lat  \
# 418464              2      89231    Neu-Ulm     Germany  48,39309564
# 418465          17-23      12103     Berlin     Germany   52,4687518
# ...

# %%
#struttura dataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418469 entries, 0 to 418468
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   FacilityID              418469 non-null  int64
#  1   NationalID              418469 non-null  object
#  2   FacilityName            417408 non-null  object
#  3   StreetName              414474 non-null  object
#  4   BuildingNumber          290136 non-null  object
#  5   PostalCode              417312 non-null  object
#  6   City                    412725 non-null  object
#  7   CountryName             418469 non-null  object
#  8   Lat                     418469 non-null  object
#  9   Long                    418469 non-null  object
#  10  CompetentAuthorityName  418469 non-null  object
#  11  MainIAActivityCode      418469 non-null  object
#  12  MainIASectorName        418469 non-null  object
#  13  MainIAActivityName      418469 non-null  object
# ...

# %%
df['MainIAActivityName'].value_counts()
# Out:
# Installations for the intensive rearing of poultry or pigs                                                       70753
# Installations for the disposal of non-hazardous waste                                                            40488
# Installations for the recovery or disposal of hazardous waste                                                    30287
# Installations for surface treatment of metals and plastic materials using an electrolytic or chemical process    27396
# Chemical installations for the production on an industrial scale of basic organic chemicals, such as:            26114
#                                                                                                                  ...
# Disposal or recycling of animal carcasses and animal waste                                                          57
# Tanning of hides and skins                                                                                          43
# ...

# %%
df['MainIAActivityName'].value_counts()
# Out:
# Installations for the intensive rearing of poultry or pigs                                                       70753
# Installations for the disposal of non-hazardous waste                                                            40488
# Installations for the recovery or disposal of hazardous waste                                                    30287
# Installations for surface treatment of metals and plastic materials using an electrolytic or chemical process    27396
# Chemical installations for the production on an industrial scale of basic organic chemicals, such as:            26114
#                                                                                                                  ...
# Disposal or recycling of animal carcasses and animal waste                                                          57
# Tanning of hides and skins                                                                                          43
# ...

# %%
df.describe(include = 'all')
# Out:
#            FacilityID     NationalID   FacilityName StreetName BuildingNumber  \
# count   418469.000000         418469         417408     414474         290136
# unique            NaN          63404          86583      67849           5570
# top               NaN  07-05-8290552  not available          -             --
# freq              NaN            259           1733       5038          63098
# mean     75546.114544            NaN            NaN        NaN            NaN
# std      80052.733732            NaN            NaN        NaN            NaN
# min          1.000000            NaN            NaN        NaN            NaN
# 25%      14757.000000            NaN            NaN        NaN            NaN
# 50%      42448.000000            NaN            NaN        NaN            NaN
# 75%     125687.000000            NaN            NaN        NaN            NaN
# max     301662.000000            NaN            NaN        NaN            NaN
#
# ...

# %%
df.plot.scatter(x="ReportingYear",y="MainIASectorName",color = "c",title="scatter plot anni/sectorName",alpha=0.5)
# Out:
# <AxesSubplot:title={'center':'scatter plot anni/sectorName'}, xlabel='ReportingYear', ylabel='MainIASectorName'>
