# %% [markdown]
# IMPORT LIBRERIE E DATASET POLLUTANT TRANSFERS

# %%
#import dataset e librerie 

import numpy as np
import pandas as pd

df = pd.read_csv('Pollutant_Transfers_new.csv' ,sep =';')


df.head()
# Out:
#    FacilityID  NationalID                                       FacilityName  \
# 0        5752  1011210116  Mondi Business Paper Austria AG Standort: Papi...
# 1        5757  1012110129           Ganahl Aktiengesellschaft (Papierfabrik)
# 2        5757  1012110129           Ganahl Aktiengesellschaft (Papierfabrik)
# 3        5758  1012310124  Fresenius Kabi Austria GmbH Zweigniederlassung...
# 4        5789  1016610659    Obersteirische Molkerei -  Standort Knittelfeld
#
#               StreetName BuildingNumber  PostalCode         City CountryName  \
# 0       Haidm�hlstra�e 2            NaN      3363.0    Amstetten     Austria
# 1           Rotfarbweg 5            NaN      6820.0     Frastanz     Austria
# 2           Rotfarbweg 5            NaN      6820.0     Frastanz     Austria
# 3     Estermannstra�e 17            NaN      4020.0         Linz     Austria
# 4  Anton-Regnerstra�e 11            NaN      8720.0  Knittelfeld     Austria
#
#          Lat       Long     CompetentAuthorityName MainIAActivityCode  \
# 0      48,05       14,8  Not transferred from EPER           EPER_6.1
# 1  47,216667   9,633333  Not transferred from EPER           EPER_6.1
# 2  47,216667   9,633333  Not transferred from EPER           EPER_6.1
# 3       48,3  14,283333  Not transferred from EPER           EPER_4.5
# 4  47,216667  14,816667  Not transferred from EPER           EPER_6.4
#
#            MainIASectorName  \
# 0  Other Annex I activities
# 1  Other Annex I activities
# 2  Other Annex I activities
# 3         Chemical industry
# 4  Other Annex I activities
#
#                                   MainIAActivityName MainIASubActivityName  \
# 0                    Pulp, paper or board production                   NaN
# 1                    Pulp, paper or board production                   NaN
# 2                    Pulp, paper or board production                   NaN
# 3                            Pharmaceutical products                   NaN
# 4  Slaughterhouses, milk, animal and vegetable ra...                   NaN
#
#    MainActivityIndicator  ReportingYear  \
# 0                   True           2001
# 1                   True           2001
# 2                   True           2001
# 3                   True           2001
# 4                   True           2001
#
#                                       PollutantName        PollutantGroupName  \
# 0  Total organic carbon (TOC) (as total C or COD/3)  Other organic substances
# 1                        Lead and compounds (as Pb)              Heavy metals
# 2  Total organic carbon (TOC) (as total C or COD/3)  Other organic substances
# 3  Total organic carbon (TOC) (as total C or COD/3)  Other organic substances
# 4  Total organic carbon (TOC) (as total C or COD/3)  Other organic substances
#
#   Quantity
# 0   625000
# 1     29,8
# 2   522000
# 3   301000
# 4    97000

# %%
df.tail()
# Out:
#        FacilityID        NationalID FacilityName       StreetName  \
# 71579       15620  vl01856089000144      LANXESS      Scheldelaan
# 71580       15620  vl01856089000144      LANXESS      Scheldelaan
# 71581       15620  vl01856089000144      LANXESS      Scheldelaan
# 71582       15620  vl01856089000144      LANXESS      Scheldelaan
# 71583       14723  vl01747956000148    VAN-O-BEL  Transvaalstraat
#
#       BuildingNumber  PostalCode       City CountryName        Lat       Long  \
# 71579            420      2040.0  Antwerpen     Belgium   51,34265  4,2788363
# 71580            420      2040.0  Antwerpen     Belgium   51,34265  4,2788363
# 71581            420      2040.0  Antwerpen     Belgium   51,34265  4,2788363
# 71582            420      2040.0  Antwerpen     Belgium   51,34265  4,2788363
# 71583             35      8793.0    Waregem     Belgium  50,900112  3,4072957
#
#                  CompetentAuthorityName MainIAActivityCode  \
# 71579  Vlaamse Milieumaatschappij (VMM)              4.(a)
# 71580  Vlaamse Milieumaatschappij (VMM)              4.(a)
# 71581  Vlaamse Milieumaatschappij (VMM)              4.(a)
# 71582  Vlaamse Milieumaatschappij (VMM)              4.(a)
# 71583  Vlaamse Milieumaatschappij (VMM)              8.(a)
#
#                                         MainIASectorName  \
# 71579                                  Chemical industry
# 71580                                  Chemical industry
# 71581                                  Chemical industry
# 71582                                  Chemical industry
# 71583  Animal and vegetable products from the food an...
#
#                                       MainIAActivityName  \
# 71579  Chemical installations for the production on a...
# 71580  Chemical installations for the production on a...
# 71581  Chemical installations for the production on a...
# 71582  Chemical installations for the production on a...
# 71583                                    Slaughterhouses
#
#       MainIASubActivityName  MainActivityIndicator  ReportingYear  \
# 71579                   NaN                  False           2016
# 71580                   NaN                   True           2016
# 71581                   NaN                  False           2016
# 71582                   NaN                  False           2016
# 71583                   NaN                   True           2016
#
#                                           PollutantName  \
# 71579  Total organic carbon (TOC) (as total C or COD/3)
# 71580                                    Total nitrogen
# 71581                                    Total nitrogen
# 71582                                    Total nitrogen
# 71583  Total organic carbon (TOC) (as total C or COD/3)
#
#              PollutantGroupName Quantity
# 71579  Other organic substances  1150000
# 71580      Inorganic substances    68500
# 71581      Inorganic substances    68500
# 71582      Inorganic substances    68500
# 71583  Other organic substances    68300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71584 entries, 0 to 71583
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   FacilityID              71584 non-null  int64
#  1   NationalID              71584 non-null  object
#  2   FacilityName            71582 non-null  object
#  3   StreetName              69898 non-null  object
#  4   BuildingNumber          51347 non-null  object
#  5   PostalCode              51141 non-null  float64
#  6   City                    70354 non-null  object
#  7   CountryName             71584 non-null  object
#  8   Lat                     71584 non-null  object
#  9   Long                    71584 non-null  object
#  10  CompetentAuthorityName  71584 non-null  object
#  11  MainIAActivityCode      71584 non-null  object
#  12  MainIASectorName        71584 non-null  object
#  13  MainIAActivityName      71584 non-null  object
#  14  MainIASubActivityName   16395 non-null  object
#  15  MainActivityIndicator   71584 non-null  bool
#  16  ReportingYear           71584 non-null  int64
#  17  PollutantName           71584 non-null  object
#  18  PollutantGroupName      71584 non-null  object
#  19  Quantity                71584 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(16)
# memory usage: 10.4+ MB

# %%
#trasformo quantità di inquinante misurato in kg in float usando una funzione lambda

df['Quantity'].apply(lambda x: float(x.replace(',','.')))
# Out:
# 0         625000.0
# 1             29.8
# 2         522000.0
# 3         301000.0
# 4          97000.0
#            ...
# 71579    1150000.0
# 71580      68500.0
# 71581      68500.0
# 71582      68500.0
# 71583      68300.0
# Name: Quantity, Length: 71584, dtype: float64
